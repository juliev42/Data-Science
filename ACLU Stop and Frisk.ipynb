# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sf_df = pd.read_excel('https://www.nyclu.org/sites/default/files/field_documents/sqf-2019.xlsx')

# %%
sf_df.head()
# Out:
#    STOP_ID_ANONY STOP_FRISK_DATE STOP_FRISK_TIME  YEAR2   MONTH2       DAY2  \
# 0              1      2019-01-02        14:30:00   2019  January  Wednesday
# 1              2      2019-01-08        02:30:00   2019  January    Tuesday
# 2              3      2019-01-12        16:54:00   2019  January   Saturday
# 3              4      2019-01-14        21:21:00   2019  January     Monday
# 4              5      2019-01-15        18:50:00   2019  January    Tuesday
#
#         STOP_WAS_INITIATED RECORD_STATUS_CODE ISSUING_OFFICER_RANK  \
# 0    Based on C/W on Scene                APP                  POM
# 1  Based on Self Initiated                APP                  POM
# 2       Based on Radio Run                APP                  POM
# 3       Based on Radio Run                APP                  POM
# 4       Based on Radio Run                APP                  POM
#
#    ISSUING_OFFICER_COMMAND_CODE           ...            \
# ...

# %%
sf_df['SUSPECT_RACE_DESCRIPTION'].value_counts()
# Out:
# BLACK                        7981
# WHITE HISPANIC               2742
# WHITE                        1215
# BLACK HISPANIC               1127
# ASIAN / PACIFIC ISLANDER      301
# (null)                         85
# AMERICAN INDIAN/ALASKAN N       8
# Name: SUSPECT_RACE_DESCRIPTION, dtype: int64

# %%
sf_df['SUSPECT_RACE_DESCRIPTION'].value_counts().plot.bar()

# %%
sf_df['SUSPECT_REPORTED_AGE'].value_counts().plot()

# %%
sf_df[sf_df['SUSPECT_ARREST_OFFENSE'] == 'null']['SUSPECT_RACE_DESCRIPTION']
# Out:
#        STOP_ID_ANONY STOP_FRISK_DATE STOP_FRISK_TIME  YEAR2   MONTH2  \
# 4                  5      2019-01-15        18:50:00   2019  January
# 141              142      2019-01-12        17:25:00   2019  January
# 144              145      2019-01-18        02:50:00   2019  January
# 252              253      2019-01-28        19:54:00   2019  January
# 1150            1151      2019-01-21        18:00:00   2019  January
# 2795            2796      2019-01-18        16:34:00   2019  January
# 3077            3078      2019-01-06        17:49:00   2019  January
# 3081            3082      2019-01-11        08:57:00   2019  January
# 3105            3106      2019-01-06        17:49:00   2019  January
# 5198            5199      2019-01-27        00:52:00   2019  January
# 5407            5408      2019-01-31        20:10:00   2019  January
# 6378            6379      2019-01-07        23:05:00   2019  January
# 6972            6973      2019-01-12        09:10:00   2019  January
# ...

# %%
pd.crosstab(sf_df['SUSPECT_RACE_DESCRIPTION'], sf_df['SUSPECT_ARREST_OFFENSE'])
# Out:
# SUSPECT_ARREST_OFFENSE     (null)  ASSAULT  AUTO STRIPPIG  BURGLARY  CPSP  \
# SUSPECT_RACE_DESCRIPTION
# (null)                         61        5              1         3     0
# AMERICAN INDIAN/ALASKAN N       5        0              0         0     0
# ASIAN / PACIFIC ISLANDER      221       20              0         8     0
# BLACK                        5482      313              3        78    19
# BLACK HISPANIC                752       50              1        14     7
# WHITE                         798       50              2        20     8
# WHITE HISPANIC               1832      127              3        39    16
#
# SUSPECT_ARREST_OFFENSE     CPW  CRIMINAL MISCHIEF  \
# SUSPECT_RACE_DESCRIPTION
# (null)                       5                  0
# AMERICAN INDIAN/ALASKAN N    0                  0
# ASIAN / PACIFIC ISLANDER     6                  6
# BLACK                      407                 74
# BLACK HISPANIC              54                 10
# ...
